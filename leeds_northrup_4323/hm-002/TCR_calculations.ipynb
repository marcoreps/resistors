# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial import Chebyshev

df=pd.read_csv('tcr_sweep_element1.csv', names=['Time', 'dut_resistance', 'dut_temperature', ], skiprows=1)

# We have one data point per time row, lets merge these into one row every 20m
df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample('20min').mean()
df = df.dropna(how='any')

# Polyfit
polyfunction = Chebyshev.fit(df['dut_temperature'], df['dut_resistance'], deg=2)

# Prepare the plot
fig,ax = plt.subplots(figsize=(16,9))
plt.xlabel('Temperature [°C]')
plt.ylabel(r'Deviation from $R_{23}$ [ppm]')
ax.set_xticks(np.arange(18, 28.1, 1))
plt.grid(True, which="both")
plt.title('Leeds Northrup 4323 Element 1 Temperature Coefficient')
xpoints = np.linspace(18, 28, 100)
r23 = polyfunction(23)

# Optionally indicate underlying data points
plt.plot(df['dut_temperature'], (df['dut_resistance']-r23)*1000, '.', alpha=0.2, label='Measured, raw')

# Plot our polyfunction between 18 and 28°C
plt.plot(xpoints, (polyfunction(xpoints)-r23)*1000, label='Measured, polyfit')

# LFG
plt.legend()

# Optionally print some more stats
derivative=polyfunction.deriv()
print("Measured α(23) = "+str(derivative(23)*1000)+" ppm/°C")
#plt.plot(xpoints, xpoints*derivative(23)-0.274)
print("Measured β = "+str(((((polyfunction(28)+polyfunction(18))/2)-polyfunction(23))/25)*1000)+" ppm/°C²")
# Out:
# Measured α(23) = 12.470234389836076 ppm/°C
# Measured β = -0.42094289616215974 ppm/°C²

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial import Chebyshev

df=pd.read_csv('tcr_sweep_element2.csv', names=['Time', 'dut_resistance', 'dut_temperature', ], skiprows=1)

# We have one data point per time row, lets merge these into one row every 20m
df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample('20min').mean()
df = df.dropna(how='any')

# Polyfit
polyfunction = Chebyshev.fit(df['dut_temperature'], df['dut_resistance'], deg=2)

# Prepare the plot
fig,ax = plt.subplots(figsize=(16,9))
plt.xlabel('Temperature [°C]')
plt.ylabel(r'Deviation from $R_{23}$ [ppm]')
ax.set_xticks(np.arange(18, 28.1, 1))
plt.grid(True, which="both")
plt.title('Leeds Northrup 4323 Element 2 Temperature Coefficient')
xpoints = np.linspace(18, 28, 100)
r23 = polyfunction(23)

# Optionally indicate underlying data points
plt.plot(df['dut_temperature'], (df['dut_resistance']-r23)*1000, '.', alpha=0.2, label='Measured, raw')

# Plot our polyfunction between 18 and 28°C
plt.plot(xpoints, (polyfunction(xpoints)-r23)*1000, label='Measured, polyfit')

# LFG
plt.legend()

# Optionally print some more stats
derivative=polyfunction.deriv()
print("Measured α(23) = "+str(derivative(23)*1000)+" ppm/°C")
#plt.plot(xpoints, xpoints*derivative(23)-0.274)
print("Measured β = "+str(((((polyfunction(28)+polyfunction(18))/2)-polyfunction(23))/25)*1000)+" ppm/°C²")
# Out:
# Measured α(23) = 10.557092611261146 ppm/°C
# Measured β = -0.33029225479822344 ppm/°C²

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial import Chebyshev

df=pd.read_csv('tcr_sweep_element3.csv', names=['Time', 'dut_resistance', 'dut_temperature', ], skiprows=1)

# We have one data point per time row, lets merge these into one row every 20m
df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample('20min').mean()
df = df.dropna(how='any')

# Polyfit
polyfunction = Chebyshev.fit(df['dut_temperature'], df['dut_resistance'], deg=2)

# Prepare the plot
fig,ax = plt.subplots(figsize=(16,9))
plt.xlabel('Temperature [°C]')
plt.ylabel(r'Deviation from $R_{23}$ [ppm]')
ax.set_xticks(np.arange(18, 28.1, 1))
plt.grid(True, which="both")
plt.title('Leeds Northrup 4323 Element 3 Temperature Coefficient')
xpoints = np.linspace(18, 28, 100)
r23 = polyfunction(23)

# Optionally indicate underlying data points
plt.plot(df['dut_temperature'], (df['dut_resistance']-r23)*1000, '.', alpha=0.2, label='Measured, raw')

# Plot our polyfunction between 18 and 28°C
plt.plot(xpoints, (polyfunction(xpoints)-r23)*1000, label='Measured, polyfit')

# LFG
plt.legend()

# Optionally print some more stats
derivative=polyfunction.deriv()
print("Measured α(23) = "+str(derivative(23)*1000)+" ppm/°C")
#plt.plot(xpoints, xpoints*derivative(23)-0.274)
print("Measured β = "+str(((((polyfunction(28)+polyfunction(18))/2)-polyfunction(23))/25)*1000)+" ppm/°C²")
# Out:
# Measured α(23) = 7.632977721756873 ppm/°C
# Measured β = -0.1220421104108027 ppm/°C²

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial import Chebyshev

df=pd.read_csv('tcr_sweep_element10.csv', names=['Time', 'dut_resistance', 'dut_temperature', ], skiprows=1)

# We have one data point per time row, lets merge these into one row every 20m
df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample('20min').mean()
df = df.dropna(how='any')

# Polyfit
polyfunction = Chebyshev.fit(df['dut_temperature'], df['dut_resistance'], deg=2)

# Prepare the plot
fig,ax = plt.subplots(figsize=(16,9))
plt.xlabel('Temperature [°C]')
plt.ylabel(r'Deviation from $R_{23}$ [ppm]')
ax.set_xticks(np.arange(18, 28.1, 1))
plt.grid(True, which="both")
plt.title('Leeds Northrup 4323 Element 10 Temperature Coefficient')
xpoints = np.linspace(18, 28, 100)
r23 = polyfunction(23)

# Optionally indicate underlying data points
plt.plot(df['dut_temperature'], (df['dut_resistance']-r23)*1000, '.', alpha=0.2, label='Measured, raw')

# Plot our polyfunction between 18 and 28°C
plt.plot(xpoints, (polyfunction(xpoints)-r23)*1000, label='Measured, polyfit')

# LFG
plt.legend()

# Optionally print some more stats
derivative=polyfunction.deriv()
print("Measured α(23) = "+str(derivative(23)*1000)+" ppm/°C")
#plt.plot(xpoints, xpoints*derivative(23)-0.274)
print("Measured β = "+str(((((polyfunction(28)+polyfunction(18))/2)-polyfunction(23))/25)*1000)+" ppm/°C²")
# Out:
# Measured α(23) = 16.506556116378682 ppm/°C
# Measured β = -0.5422696262849058 ppm/°C²

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial import Chebyshev

df=pd.read_csv('tcr_sweep_element9.csv', names=['Time', 'dut_resistance', 'dut_temperature', ], skiprows=1)

# We have one data point per time row, lets merge these into one row every 20m
df['Time'] = pd.to_datetime(df['Time'])
df = df.set_index('Time')
df = df.resample('20min').mean()
df = df.dropna(how='any')

# Polyfit
polyfunction = Chebyshev.fit(df['dut_temperature'], df['dut_resistance'], deg=2)

# Prepare the plot
fig,ax = plt.subplots(figsize=(16,9))
plt.xlabel('Temperature [°C]')
plt.ylabel(r'Deviation from $R_{23}$ [ppm]')
ax.set_xticks(np.arange(18, 28.1, 1))
plt.grid(True, which="both")
plt.title('Leeds Northrup 4323 Element 9 Temperature Coefficient')
xpoints = np.linspace(18, 28, 100)
r23 = polyfunction(23)

# Optionally indicate underlying data points
plt.plot(df['dut_temperature'], (df['dut_resistance']-r23)*1000, '.', alpha=0.2, label='Measured, raw')

# Plot our polyfunction between 18 and 28°C
plt.plot(xpoints, (polyfunction(xpoints)-r23)*1000, label='Measured, polyfit')

# LFG
plt.legend()

# Optionally print some more stats
derivative=polyfunction.deriv()
print("Measured α(23) = "+str(derivative(23)*1000)+" ppm/°C")
#plt.plot(xpoints, xpoints*derivative(23)-0.274)
print("Measured β = "+str(((((polyfunction(28)+polyfunction(18))/2)-polyfunction(23))/25)*1000)+" ppm/°C²")
# Out:
# Measured α(23) = 10.345635331252268 ppm/°C
# Measured β = -0.06759501957731118 ppm/°C²
